# %%
import pandas as pd
import numpy as np
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("Test_img/sharapova1.jpg")
img.shape
# Out:
# (555, 700, 3)

# %%
plt.imshow(img)

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_img, cmap='gray')
gray_img.shape
# Out:
# (555, 700)

# %%
img
# Out:
# array([[[200, 179, 157],
#         [200, 179, 157],
#         [200, 179, 157],
#         ...,
#         [195, 181, 158],
#         [194, 180, 157],
#         [193, 179, 156]],
#
#        [[200, 179, 157],
#         [200, 179, 157],
#         [200, 179, 157],
#         ...,
#         [196, 182, 159],
#         [194, 180, 157],
#         [193, 179, 156]],
#
#        [[200, 179, 157],
#         [200, 179, 157],
#         [200, 179, 157],
#         ...,
#         [196, 182, 159],
#         [195, 181, 158],
#         [193, 179, 156]],
#
#        ...,
#
#        [[ 26,  58, 158],
#         [ 30,  59, 163],
#         [ 33,  59, 165],
#         ...,
#         [154, 120,  84],
#         [154, 120,  84],
#         [154, 120,  84]],
#
#        [[ 30,  62, 162],
#         [ 32,  61, 165],
#         [ 35,  61, 167],
#         ...,
#         [154, 120,  84],
#         [154, 120,  84],
#         [154, 120,  84]],
#
#        [[ 35,  67, 167],
#         [ 34,  63, 167],
#         [ 36,  62, 168],
# ...
